# %%
import pandas as pa
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pa.read_csv(r"C:\Users\chaud\Downloads\Cases (Oldest) 1970 (1).csv")
df.head()
# Out:
#    Date   Code     CommodityId  CommodityName  DistrictName  DistrictCode  \
# 0  1970  State  Andhra Pradesh           10.0          85.0           1.0
# 1  1970  State           Assam           29.0         110.0          27.0
# 2  1970  State           Bihar           37.0         416.0          63.0
# 3  1970  State         Gujarat           19.0          62.0           3.0
# 4  1970  State         Haryana           21.0          82.0           4.0
#
#    Stock  CommodityStock  TotalStock
# 0    9.0            85.0        25.0
# 1   31.0            81.0       143.0
# 2   51.0           339.0       645.0
# 3   10.0            68.0        43.0
# 4   22.0            77.0        69.0

# %%
#DAY 2 CHECKING FOR THE MISSING DATA .
import pandas as pa
df = pa.read_csv(r"C:\Users\chaud\Downloads\Cases (Oldest) 1970 (1).csv")
print(df.head())  # I have to Check  if df is loaded and data is visible

df.isnull().sum() #Use for to check the missing and null values present in the data sets
# Out:
#    Date   Code     CommodityId  CommodityName  DistrictName  DistrictCode  \
# 0  1970  State  Andhra Pradesh           10.0          85.0           1.0
# 1  1970  State           Assam           29.0         110.0          27.0
# 2  1970  State           Bihar           37.0         416.0          63.0
# 3  1970  State         Gujarat           19.0          62.0           3.0
# 4  1970  State         Haryana           21.0          82.0           4.0
#
#    Stock  CommodityStock  TotalStock
# 0    9.0            85.0        25.0
# 1   31.0            81.0       143.0
# 2   51.0           339.0       645.0
# 3   10.0            68.0        43.0
# 4   22.0            77.0        69.0
# Date               0
# Code               0
# CommodityId        0
# CommodityName     13
# DistrictName       5
# DistrictCode      16
# Stock             15
# CommodityStock     4
# TotalStock         7
# dtype: int64

# %%
#NOW ITS TIME TO REMOVE THE DUPLICATE VALUES PRESENT IN DATASETS 
import pandas as pa
df = pa.read_csv(r"C:\Users\chaud\Downloads\Cases (Oldest) 1970 (1).csv")
print(df.head())
df.drop_duplicates(inplace=True)
print(df)
# Out:
#    Date   Code     CommodityId  CommodityName  DistrictName  DistrictCode  \
# 0  1970  State  Andhra Pradesh           10.0          85.0           1.0
# 1  1970  State           Assam           29.0         110.0          27.0
# 2  1970  State           Bihar           37.0         416.0          63.0
# 3  1970  State         Gujarat           19.0          62.0           3.0
# 4  1970  State         Haryana           21.0          82.0           4.0
#
#    Stock  CommodityStock  TotalStock
# 0    9.0            85.0        25.0
# 1   31.0            81.0       143.0
# 2   51.0           339.0       645.0
# 3   10.0            68.0        43.0
# 4   22.0            77.0        69.0
#     Date               Code        CommodityId  CommodityName  DistrictName  \
# 0   1970              State     Andhra Pradesh           10.0          85.0
# 1   1970              State              Assam           29.0         110.0
# ...
